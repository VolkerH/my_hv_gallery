# %% [markdown]
# ## 3D Scatterplot using ipyvolume
#
# Copy and paste from
# https://ipyvolume.readthedocs.io/en/latest/
#
#
# ## Prerequisite
#
#
# you need a web browser that supports WebGL... For me, Firefox works.
#
# Moreover, if you use a script blocker such as NoScript make sure it is disabled when you try to run this notebook.
#
#
# ## Windows users
#
# make sure you read the comment about `fcntl` in the markdown cell further down.

# %%
import ipyvolume as ipv
import numpy as np
x, y, z = np.random.random((3, 10000))
ipv.quickscatter(x, y, z, size=1, marker="sphere", color="green")
# Out:
# ...
#       dtype='<U5'), color_selected=array('white',
#       dtype='<U5'), geo='sphere', size=array(1), size_selected=array(2.6), x=array([ 0.26975409,  0.04029971,  0.53775087, ...,  0.11743338,
#         0.6598373 ,  0.29931225]), y=array([ 0.93329411,  0.54548282,  0.02165355, ...,  0.01780641,
#         0.37713405,  0.13915722]), z=array([ 0.26292844,  0.58255327,  0.00251839, ...,  0.95097696,
#         0.7324446 ,  0.93965055]))], style={'axes': {'visible': True, 'label': {'color': 'black'}, 'ticklabel': {'color': 'black'}, 'color': 'black'}, 'box': {'visible': True}, 'background-color': 'white'}, tf=None, width=400, xlim=[0.0, 1.0], ylim=[0.0, 1.0], zlim=[0.0, 1.0]),))

# %%
ipv.quickscatter??

# %% [markdown]
# # Try linking bokeh and Ipyvolume
#
# example code
# http://ipyvolume.readthedocs.io/en/latest/bokeh.html
#
#
# Note: need to install vaex for the example data
# this in turn imports `fcntl`, which is not available on windows and thus causes an error.
# Including a dummy `fcntl.py` in this folder fixes the issue and lets us generate the plots.
# However, such a dummy `fcntl.py` in your path can upset your jupyter notebook on Unix-based systems.
# Therefore, windows users should rename the file `fctnl.py_dis` in this folder to `fcntl.py`.

# %%
import ipyvolume
import ipyvolume as ipv
import vaex
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
import ipyvolume.bokeh
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="92e0f5c3-647e-4126-8d9c-6636344365aa">Loading BokehJS ...</span>
#     </div>

# %%
ds = vaex.example()
N = 10000

# %%
ipv.figure()
quiver = ipv.quiver(ds.data.x[:N],  ds.data.y[:N],  ds.data.z[:N],
                    ds.data.vx[:N], ds.data.vy[:N], ds.data.vz[:N],
                    size=1, size_selected=5, color_selected="grey")
ipv.xyzlim(-30, 30)
tools = "wheel_zoom,box_zoom,box_select,lasso_select,help,reset,"
#p = figure(title="E Lz space", tools=tools, webgl=True, width=500, height=500)
p = figure(title="E Lz space", tools=tools, width=500, height=500)

r = p.circle(ds.data.Lz[:N], ds.data.E[:N],color="navy", alpha=0.2)
# A 'trick' from ipyvolume to link the selection (one way traffic atm)
ipyvolume.bokeh.link_data_source_selection_to_widget(r.data_source, quiver, 'selected')

# %%
ipv.show()
show(p)
# Out:
# ...
#       dtype='<U4'), geo='arrow', size=array(1), size_selected=array(5), vx=array([  53.276722 ,  252.810791 ,   96.276474 , ...,   63.2067719,
#          20.562912 ,   62.0345764]), vy=array([ 288.386047 ,  -69.9498444,  226.440201 , ...,  135.197815 ,
#          72.8022614,  -94.5759735]), vz=array([-95.2649078, -56.3121033, -34.7527161, ..., -76.7877426,
#         58.2470703,  14.9864044]), x=array([ -0.77747077,   3.77427316,   1.3757627 , ...,   4.2751708 ,
#        -16.5933533 ,  -1.29029   ]), y=array([  2.10626292,   2.23387194,  -6.3283844 , ...,  12.3548756 ,
#         12.5755587 ,  -4.7683897 ]), z=array([  1.93743467,   3.76209331,   2.63250017, ...,  -5.19266605,
#         15.1321297 ,  -0.78672153]))], style={'axes': {'visible': True, 'label': {'color': 'black'}, 'ticklabel': {'color': 'black'}, 'color': 'black'}, 'box': {'visible': True}, 'background-color': 'white'}, tf=None, width=400, xlim=[-30.0, 30.0], ylim=[-30.0, 30.0], zlim=[-30.0, 30.0]),))
# ...

# %% [markdown]
# ## It works ! The selection in the 2D Bokeh plot is linked to the 3D Quiver plot ! Cool.
#
# ![](./bokeh_ipyvolume.gif)
